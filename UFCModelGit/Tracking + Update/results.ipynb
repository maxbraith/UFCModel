# %%
import requests
from bs4 import BeautifulSoup
import re
import csv
from csv import writer
import random
import time
import pandas as pd
import csv
import numpy as np
import math
import itertools
import concurrent.futures
import datetime
import datetime
from datetime import date

# %%
df = pd.read_csv('mockPreds.csv')
df.head()
# Out:
#                                Fight  Prediction         Predicted  Winner  \
# 0     Edson Barboza vs Lerone Murphy       0.585     Lerone Murphy     NaN
# 1  Khaos Williams vs Carlston Harris       0.400    Khaos Willaims     NaN
# 2   Themba Gorimbo vs Ramiz Brahimaj       0.550    Ramiz Brahimaj     NaN
# 3  Adrian Yanez vs Vinicius Salvador       0.720  Vinicus Salvador     NaN
#
#       Result
# 0  dasooijga
# 1        NaN
# 2        NaN
# 3        NaN

# %%
dfCheck = pd.read_csv('databaseUpdated2024-05-22.csv')
dfCheck.head()
# Out:
#                                fight       redCorner         blueCorner  \
# 0     Edson Barboza vs Lerone Murphy   Edson Barboza      Lerone Murphy
# 1  Khaos Williams vs Carlston Harris  Khaos Williams    Carlston Harris
# 2   Ramiz Brahimaj vs Themba Gorimbo  Themba Gorimbo     Ramiz Brahimaj
# 3  Adrian Yanez vs Vinicius Salvador    Adrian Yanez  Vinicius Salvador
# 4      Angela Hill vs Luana Pinheiro  Luana Pinheiro        Angela Hill
#
#            winner                                event          referee  \
# 0   Lerone Murphy  UFC Fight Night: Barboza vs. Murphy        Herb Dean
# 1  Khaos Williams  UFC Fight Night: Barboza vs. Murphy  Dan Miragliotta
# 2  Themba Gorimbo  UFC Fight Night: Barboza vs. Murphy       Mark Smith
# 3    Adrian Yanez  UFC Fight Night: Barboza vs. Murphy    Chris Tognoni
# 4     Angela Hill  UFC Fight Night: Barboza vs. Murphy        Herb Dean
#
#       method_of_victory        date     venue title_fight  ...  \
# 0  Decision - Unanimous  05.18.2024  UFC Apex          no  ...
# 1                KO/TKO  05.18.2024  UFC Apex          no  ...
# 2  Decision - Unanimous  05.18.2024  UFC Apex          no  ...
# 3                KO/TKO  05.18.2024  UFC Apex          no  ...
# 4            Submission  05.18.2024  UFC Apex          no  ...
#
#   redCorner_subs_attempted  blueCorner_subs_attempted  round  time  \
# 0                        0                          0      5  5:00
# 1                        0                          0      1  1:30
# 2                        0                          0      3  5:00
# 3                        0                          0      1  2:47
# 4                        0                          1      2  4:12
#
#    redCorner_height  blueCorner_height  redCorner_reach  blueCorner_reach  \
# 0            5' 11"              5' 9"              75"               73"
# 1             6' 0"              6' 0"              77"               76"
# 2             6' 1"             5' 10"              77"               72"
# 3             5' 7"              5' 7"              70"               70"
# 4             5' 2"              5' 3"              62"               64"
#
#    redCorner_stance blueCorner_stance
# 0          Orthodox          Orthodox
# 1          Orthodox          Orthodox
# 2          Orthodox          Orthodox
# 3          Orthodox          Southpaw
# 4          Orthodox          Orthodox
#
# [5 rows x 45 columns]

# %%
for index, row in df.iterrows():
    if(type(row['Result']) != str):
        fight = row['Fight']
        redAndBlue = fight.split(' vs ')
        redCorner = redAndBlue[0]
        blueCorner = redAndBlue[1]
        prediction = row['Prediction']
        #find indexes of fight match
        redCornerCheck = dfCheck[:20][dfCheck['redCorner'][:20] == redCorner].index[0]
        blueCornerCheck = dfCheck[:20][dfCheck['blueCorner'][:20] == blueCorner].index[0]
        if(int(redCornerCheck) == int(blueCornerCheck)):
            indexCheck = int(redCornerCheck)
            winner = dfCheck.loc[indexCheck, 'winner']
            if(winner == redCorner and float(prediction) < 0.5):
                df.loc[index, 'Result'] = 'Correct'
                df.loc[index, 'Winner'] = winner
            elif(winner == blueCorner and float(prediction) > 0.5):
                df.loc[index, 'Result'] = 'Correct'
                df.loc[index, 'Winner'] = winner
            else:
                df.loc[index, 'Result'] = 'Incorrect'
                df.loc[index, 'Winner'] = winner
df.head()
# Out:
# /var/folders/pw/f4_6q0l977bcqprlylly2d1w0000gq/T/ipykernel_56563/3603916460.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Khaos Williams' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[index, 'Winner'] = winner
#                                Fight  Prediction         Predicted  \
# 0     Edson Barboza vs Lerone Murphy       0.585     Lerone Murphy
# 1  Khaos Williams vs Carlston Harris       0.400    Khaos Willaims
# 2   Themba Gorimbo vs Ramiz Brahimaj       0.550    Ramiz Brahimaj
# 3  Adrian Yanez vs Vinicius Salvador       0.720  Vinicus Salvador
#
#            Winner     Result
# 0             NaN  dasooijga
# 1  Khaos Williams    Correct
# 2  Themba Gorimbo  Incorrect
# 3    Adrian Yanez  Incorrect
