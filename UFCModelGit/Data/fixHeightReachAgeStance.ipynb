# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('databaseUpdated-01.22.2024.csv')
df.head()
# Out:
#                                     fight          redCorner  \
# 0    Dricus Du Plessis vs Sean Strickland    Sean Strickland
# 1  Raquel Pennington vs Mayra Bueno Silva  Raquel Pennington
# 2               Neil Magny vs Mike Malott         Neil Magny
# 3    Chris Curtis vs Marc Andre Barriault       Chris Curtis
# 4           Movsar Evloev vs Arnold Allen       Arnold Allen
#
#              blueCorner             winner  \
# 0     Dricus Du Plessis  Dricus Du Plessis
# 1     Mayra Bueno Silva  Raquel Pennington
# 2           Mike Malott         Neil Magny
# 3  Marc Andre Barriault       Chris Curtis
# 4         Movsar Evloev      Movsar Evloev
#
#                                 event               referee  \
# 0  UFC 297: Strickland vs. Du Plessis          Marc Goddard
# 1  UFC 297: Strickland vs. Du Plessis           Jerin Valel
# 2  UFC 297: Strickland vs. Du Plessis       Kevin MacDonald
# 3  UFC 297: Strickland vs. Du Plessis  Todd Ronald Anderson
# ...

# %%
#In this df nans ar represented as '---' - replacing this with nan
df.replace('---', np.nan, inplace=True)
df.replace('--', np.nan, inplace=True)

# %%
#specify the columns of interest
columns_of_interest = ['redCorner_height', 'blueCorner_height', 'redCorner_reach','blueCorner_reach', 'redCorner_stance']

#find the first row with NaN value in the specified columns
first_row_with_nan = df[df[columns_of_interest].isnull().any(axis=1)].head(1)

#print only the values in columns needed for analysis
values_to_print = first_row_with_nan[['redCorner', 'blueCorner', 'redCorner_height', 'blueCorner_height', 'redCorner_reach','blueCorner_reach', 'redCorner_stance']]
print(values_to_print)

#print the total number of NaN values in the specified columns
total_nans = df[columns_of_interest].isnull().sum().sum()
print(total_nans)
# Out:
#        redCorner        blueCorner redCorner_height blueCorner_height  \
# 5710  Terry Etim  Edward Faaloloto            6' 1"               NaN
#
#      redCorner_reach blueCorner_reach redCorner_stance
# 5710             73"              70"         Orthodox
# 917

# %%
#fixing inconsistencies
df.at[5710, 'blueCorner_height'] = '6\' 1"'

df.at[5791, 'blueCorner_reach'] = '77'

df.at[5826, 'redCorner_stance'] = 'Orthodox'

df.at[5843, 'redCorner_stance'] = 'Orthodox'

df.at[5826, 'blueCorner_height'] = '5\' 9"'

df.at[5915, 'redCorner_height'] = '6\' 0"'

df.at[5983, 'blueCorner_reach'] = '77'

df.at[6037, 'blueCorner_reach'] = '74'

# %%
#fix inconsistencies
df.loc[df['redCorner'] == 'Josh Bryant', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Josh Bryant', 'blueCorner_reach'] = '73'

df = df[df['redCorner'] != 'Steve Lopez']

df.loc[df['redCorner'] == 'Sako Chivitchian', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Sako Chivitchian', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Sako Chivitchian', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Sako Chivitchian', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Ian Loveland', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Ian Loveland', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Maciej Jewtuszko', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Maciej Jewtuszko', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Alex Soto', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Alex Soto', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Pedro Nobre', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Pedro Nobre', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Adam Cella', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Adam Cella', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Estevan Payan', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Estevan Payan', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Nandor Guelmino', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Nandor Guelmino', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Peggy Morgan', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Peggy Morgan', 'blueCorner_stance'] = 'Orthodox'

df.at[4919, 'blueCorner_age'] = 36

df.loc[df['redCorner'] == 'Chris Holdsworth', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Chris Holdsworth', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Chris Indich', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Chris Indich', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Humberto Brown Morrison', 'redCorner_stance'] = 'Switch'
df.loc[df['blueCorner'] == 'Humberto Brown Morrison', 'blueCorner_stance'] = 'Switch'

df.loc[df['redCorner'] == 'Matt Van Buren', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Matt Van Buren', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Nazareno Malegarie', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Nazareno Malegarie', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Paul Redmond', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Paul Redmond', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Nazareno Malegarie', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Nazareno Malegarie', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Bruno Korea', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Bruno Korea', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Emily Kagan', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Emily Kagan', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Abner Lloveras', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Abner Lloveras', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Marcin Wrzosek', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Marcin Wrzosek', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Hayder Hassan', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Hayder Hassan', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Martin Svensson', 'redCorner_stance'] = 'Southpaw'
df.loc[df['blueCorner'] == 'Martin Svensson', 'blueCorner_stance'] = 'Southpaw'

df.loc[df['redCorner'] == 'Dileno Lopes', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Dileno Lopes', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Fernando Bruno', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Fernando Bruno', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Enrique Marin', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Enrique Marin', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Horacio Gutierrez', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Horacio Gutierrez', 'blueCorner_stance'] = 'Orthodox'

df.loc[df['redCorner'] == 'Karine Gevorgyan', 'redCorner_stance'] = 'Orthodox'
df.loc[df['blueCorner'] == 'Karine Gevorgyan', 'blueCorner_stance'] = 'Orthodox'

df.at[3013, 'blueCorner_age'] = 35

df.at[3226, 'blueCorner_age'] = 35

# %%
print(len(df))
df.drop(4268, inplace=True)
df.drop(4367, inplace=True)
df.drop(4449, inplace=True)
df.drop(4644, inplace=True)
df.drop(4667, inplace=True)
df.drop(5148, inplace=True)
df.drop(5293, inplace=True)
df.drop(5512, inplace=True)
df.drop(5513, inplace=True)
df.drop(5681, inplace=True)
df.drop(5846, inplace=True)
print(len(df))
# Out:
# 7469
# 7458

# %%
redCorner_reaches = df.loc[:6161, 'blueCorner_reach'].tolist()
print(list(set(redCorner_reaches)))
# Out:
# ['6', '60"', '71"', '70', '67"', '62"', '66"', '77"', '72"', '75"', '76"', '61"', '80"', '65"', '72', '58"', '73"', '8', '79"', '59"', '81"', '68"', '83"', 'N', '74', '74"', '64"', '82"', '84"', '63"', '78"', '71', '70"', '69"', '7', '77']

# %%
df.loc[df['redCorner'] == 'Jay Cucciniello', 'redCorner_reach'] = '68'
df.loc[df['blueCorner'] == 'Jay Cucciniello', 'blueCorner_reach'] = '68'

df.loc[df['redCorner'] == 'Kalindra Faria', 'redCorner_reach'] = '62'
df.loc[df['blueCorner'] == 'Kalindra Faria', 'blueCorner_reach'] = '62'

df.loc[df['redCorner'] == 'Pearl Gonzalez', 'redCorner_reach'] = '68'
df.loc[df['blueCorner'] == 'Pearl Gonzalez', 'blueCorner_reach'] = '68'

df.loc[df['redCorner'] == 'Joe Gigliotti', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Joe Gigliotti', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Yusuke Kasuya', 'redCorner_reach'] = '67'
df.loc[df['blueCorner'] == 'Yusuke Kasuya', 'blueCorner_reach'] = '67'

df.loc[df['redCorner'] == 'Anna Elmose', 'redCorner_reach'] = '65'
df.loc[df['blueCorner'] == 'Anna Elmose', 'blueCorner_reach'] = '65'

df.loc[df['redCorner'] == 'Kelly Faszholz', 'redCorner_reach'] = '67'
df.loc[df['blueCorner'] == 'Kelly Faszholz', 'blueCorner_reach'] = '67'

df.loc[df['redCorner'] == 'Ian Entwistle', 'redCorner_reach'] = '64'
df.loc[df['blueCorner'] == 'Ian Entwistle', 'blueCorner_reach'] = '64'

df.loc[df['redCorner'] == 'Yui Chul Nam', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Yui Chul Nam', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Horacio Gutierrez', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Horacio Gutierrez', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Vernon Ramos Ho', 'redCorner_reach'] = '67'
df.loc[df['blueCorner'] == 'Vernon Ramos Ho', 'blueCorner_reach'] = '67'

df.loc[df['redCorner'] == 'Roldan Sangchaan', 'redCorner_reach'] = '65'
df.loc[df['blueCorner'] == 'Roldan Sangchaan', 'blueCorner_reach'] = '65'

df.loc[df['redCorner'] == 'Nolan Ticman', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Nolan Ticman', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Jessica Rakoczy', 'redCorner_reach'] = '68'
df.loc[df['blueCorner'] == 'Jessica Rakoczy', 'blueCorner_reach'] = '68'

df.loc[df['redCorner'] == 'Izabela Badurek', 'redCorner_reach'] = '65'
df.loc[df['blueCorner'] == 'Izabela Badurek', 'blueCorner_reach'] = '65'

df.loc[df['redCorner'] == 'Bentley Syler', 'redCorner_reach'] = '68'
df.loc[df['blueCorner'] == 'Bentley Syler', 'blueCorner_reach'] = '68'

df.loc[df['redCorner'] == 'Larissa Pacheco', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Larissa Pacheco', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Roman Salazar', 'redCorner_reach'] = '68'
df.loc[df['blueCorner'] == 'Roman Salazar', 'blueCorner_reach'] = '68'

df.loc[df['redCorner'] == 'Tateki Matsuda', 'redCorner_reach'] = '66'
df.loc[df['blueCorner'] == 'Tateki Matsuda', 'blueCorner_reach'] = '66'

df.loc[df['redCorner'] == 'Alexis Dufresne', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Alexis Dufresne', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Emily Kagan', 'redCorner_reach'] = '66'
df.loc[df['blueCorner'] == 'Emily Kagan', 'blueCorner_reach'] = '66'

df.loc[df['redCorner'] == 'Jumabieke Tuerxun', 'redCorner_reach'] = '67'
df.loc[df['blueCorner'] == 'Jumabieke Tuerxun', 'blueCorner_reach'] = '67'

df.loc[df['redCorner'] == 'Ramiro Hernandez', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Ramiro Hernandez', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Julie Kedzie', 'redCorner_reach'] = '65'
df.loc[df['blueCorner'] == 'Julie Kedzie', 'blueCorner_reach'] = '65'

df.loc[df['redCorner'] == 'Jose Maria', 'redCorner_reach'] = '65'
df.loc[df['blueCorner'] == 'Jose Maria', 'blueCorner_reach'] = '65'

df.loc[df['redCorner'] == 'Rosi Sexton', 'redCorner_reach'] = '63'
df.loc[df['blueCorner'] == 'Rosi Sexton', 'blueCorner_reach'] = '63'

df.loc[df['redCorner'] == 'Marcos Vinicius', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Marcos Vinicius', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Joao Zeferino', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Joao Zeferino', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Yasuhiro Urushitani', 'redCorner_reach'] = '67'
df.loc[df['blueCorner'] == 'Yasuhiro Urushitani', 'blueCorner_reach'] = '67'

df.loc[df['redCorner'] == 'John Teixeira', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'John Teixeira', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Joseph Sandoval', 'redCorner_reach'] = '66'
df.loc[df['blueCorner'] == 'Joseph Sandoval', 'blueCorner_reach'] = '66'

df.loc[df['redCorner'] == 'Waylon Lowe', 'redCorner_reach'] = '69'
df.loc[df['blueCorner'] == 'Waylon Lowe', 'blueCorner_reach'] = '69'

df.loc[df['redCorner'] == 'Charlie Ward', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Charlie Ward', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Kwan Ho Kwak', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Kwan Ho Kwak', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Keith Berish', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Keith Berish', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Cody East', 'redCorner_reach'] = '77'
df.loc[df['blueCorner'] == 'Cody East', 'blueCorner_reach'] = '77'

df.loc[df['redCorner'] == 'Alberto Uda', 'redCorner_reach'] = '78'
df.loc[df['blueCorner'] == 'Alberto Uda', 'blueCorner_reach'] = '78'

df.loc[df['redCorner'] == 'Cesar Arzamendia', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Cesar Arzamendia', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Cory Hendricks', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Cory Hendricks', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Filip Pejic', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Filip Pejic', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Jonavin Webb', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Jonavin Webb', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Hayder Hassan', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Hayder Hassan', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Bubba Bush', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Bubba Bush', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Anthony Christodoulou', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Anthony Christodoulou', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Steve Montgomery', 'redCorner_reach'] = '76'
df.loc[df['blueCorner'] == 'Steve Montgomery', 'blueCorner_reach'] = '76'

df.loc[df['redCorner'] == 'Alan Omer', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Alan Omer', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Niklas Backstrom', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Niklas Backstrom', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Ricardo Abreu', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Ricardo Abreu', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Wendell Oliveira Marques', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Wendell Oliveira Marques', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Luiz Dutra', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Luiz Dutra', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Marcin Bandel', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Marcin Bandel', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Jorge de Oliveira', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Jorge de Oliveira', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Jake Lindsey', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Jake Lindsey', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Richardson Moreira', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Richardson Moreira', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Matt Van Buren', 'redCorner_reach'] = '77'
df.loc[df['blueCorner'] == 'Matt Van Buren', 'blueCorner_reach'] = '77'

df.loc[df['redCorner'] == 'David Michaud', 'redCorner_reach'] = '77'
df.loc[df['blueCorner'] == 'David Michaud', 'blueCorner_reach'] = '77'

df.loc[df['redCorner'] == 'Juan Manuel Puig', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Juan Manuel Puig', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Wagner Silva', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Wagner Silva', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Tor Troeng', 'redCorner_reach'] = '78'
df.loc[df['blueCorner'] == 'Tor Troeng', 'blueCorner_reach'] = '78'

df.loc[df['redCorner'] == 'Sai Wang', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Sai Wang', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Anying Wang', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Anying Wang', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Hernani Perpetuo', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Hernani Perpetuo', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Andreas Stahl', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Andreas Stahl', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Robert Drysdale', 'redCorner_reach'] = '79'
df.loc[df['blueCorner'] == 'Robert Drysdale', 'blueCorner_reach'] = '79'

df.loc[df['redCorner'] == 'Chris Indich', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Chris Indich', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Chris Holdsworth', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Chris Holdsworth', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Anthony Lapsley', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Anthony Lapsley', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Thiago Perpetuo', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Thiago Perpetuo', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Albert Cheng', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Albert Cheng', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Bruno Santos', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Bruno Santos', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Ben Wall', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Ben Wall', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Nandor Guelmino', 'redCorner_reach'] = '77'
df.loc[df['blueCorner'] == 'Nandor Guelmino', 'blueCorner_reach'] = '77'

df.loc[df['redCorner'] == 'Keith Wisniewski', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Keith Wisniewski', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Pascal Krauss', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Pascal Krauss', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Chris Spang', 'redCorner_reach'] = '77'
df.loc[df['blueCorner'] == 'Chris Spang', 'blueCorner_reach'] = '77'

df.loc[df['redCorner'] == 'Papy Abedi', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Papy Abedi', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Jon Manley', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Jon Manley', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Nah Shon Burrell', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Nah Shon Burrell', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Colin Fletcher', 'redCorner_reach'] = '78'
df.loc[df['blueCorner'] == 'Colin Fletcher', 'blueCorner_reach'] = '78'

df.loc[df['redCorner'] == 'Nick Penner', 'redCorner_reach'] = '77'
df.loc[df['blueCorner'] == 'Nick Penner', 'blueCorner_reach'] = '77'

df.loc[df['redCorner'] == 'Anistavio Medeiros', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Anistavio Medeiros', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Delson Heleno', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Delson Heleno', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Buddy Roberts', 'redCorner_reach'] = '76'
df.loc[df['blueCorner'] == 'Buddy Roberts', 'blueCorner_reach'] = '76'

df.loc[df['redCorner'] == 'Jason Miller', 'redCorner_reach'] = '76'
df.loc[df['blueCorner'] == 'Jason Miller', 'blueCorner_reach'] = '76'

df.loc[df['redCorner'] == 'Oli Thompson', 'redCorner_reach'] = '75'
df.loc[df['blueCorner'] == 'Oli Thompson', 'blueCorner_reach'] = '75'

df.loc[df['redCorner'] == 'Dan Stittgen', 'redCorner_reach'] = '71'
df.loc[df['blueCorner'] == 'Dan Stittgen', 'blueCorner_reach'] = '71'

df.loc[df['redCorner'] == 'Jesse Bongfeldt', 'redCorner_reach'] = '72'
df.loc[df['blueCorner'] == 'Jesse Bongfeldt', 'blueCorner_reach'] = '72'

df.loc[df['redCorner'] == 'Chuck ONeil', 'redCorner_reach'] = '76'
df.loc[df['blueCorner'] == 'Chuck ONeil', 'blueCorner_reach'] = '76'

df.loc[df['redCorner'] == 'Ryan McGillivray', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Ryan McGillivray', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Tom Blackledge', 'redCorner_reach'] = '77'
df.loc[df['blueCorner'] == 'Tom Blackledge', 'blueCorner_reach'] = '77'

df.loc[df['redCorner'] == 'Pat Audinwood', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Pat Audinwood', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Mike Lullo', 'redCorner_reach'] = '70'
df.loc[df['blueCorner'] == 'Mike Lullo', 'blueCorner_reach'] = '70'

df.loc[df['redCorner'] == 'Todd Brown', 'redCorner_reach'] = '74'
df.loc[df['blueCorner'] == 'Todd Brown', 'blueCorner_reach'] = '74'

df.loc[df['redCorner'] == 'Jamie Yager', 'redCorner_reach'] = '73'
df.loc[df['blueCorner'] == 'Jamie Yager', 'blueCorner_reach'] = '73'

df.loc[df['redCorner'] == 'Ednaldo Oliveira', 'redCorner_reach'] = '82'
df.loc[df['blueCorner'] == 'Ednaldo Oliveira', 'blueCorner_reach'] = '82'

# %%
df.at[5939, 'blueCorner_reach'] = '73'

df.at[5990, 'blueCorner_reach'] = '73'

df.at[6013, 'blueCorner_reach'] = '74'

df.at[6024, 'blueCorner_reach'] = '73'

df.at[6045, 'blueCorner_reach'] = '73'

df.at[6086, 'blueCorner_reach'] = '76'

df.at[6108, 'blueCorner_reach'] = '70'

df.at[6123, 'blueCorner_reach'] = '76'

df.at[6129, 'blueCorner_reach'] = '70'

df.at[6136, 'blueCorner_reach'] = '71'

df.at[6139, 'blueCorner_reach'] = '75'

df.at[6161, 'blueCorner_reach'] = '73'

df.at[3157, 'blueCorner_reach'] = '67'

df.at[3299, 'blueCorner_reach'] = '67'

df.at[3414, 'blueCorner_reach'] = '69'

df.at[3560, 'blueCorner_reach'] = '65'

df.at[3665, 'blueCorner_reach'] = '69'

df.at[3720, 'blueCorner_reach'] = '69'

df.at[3754, 'blueCorner_reach'] = '66'

df.at[3851, 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Cristina Stanciu', 'blueCorner_reach'] = '64'

df.loc[df['blueCorner'] == 'Rin Nakai', 'blueCorner_reach'] = '61'

df.loc[df['blueCorner'] == 'Ericka Almeida', 'blueCorner_reach'] = '69'

df.loc[df['blueCorner'] == 'Sirwan Kakai', 'blueCorner_reach'] = '68'

df.at[4127, 'blueCorner_reach'] = '66'

df.at[4201, 'blueCorner_reach'] = '67'

df.at[4237, 'blueCorner_reach'] = '68'

df.loc[df['blueCorner'] == 'Rocky Lee', 'blueCorner_reach'] = '68'

df.loc[df['blueCorner'] == 'Milana Dudieva', 'blueCorner_reach'] = '62'

df.loc[df['blueCorner'] == 'Shayna Baszler', 'blueCorner_reach'] = '68'

df.loc[df['blueCorner'] == 'Shane Howell', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Chris Heatherly', 'blueCorner_reach'] = '69'

df.loc[df['blueCorner'] == 'Leonardo Morales', 'blueCorner_reach'] = '68'

df.loc[df['blueCorner'] == 'Rodolfo Rubio Perez', 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Tim Gorman', 'blueCorner_reach'] = '68'

df.loc[df['blueCorner'] == 'Jianping Yang', 'blueCorner_reach'] = '65'

df.loc[df['blueCorner'] == 'Tina Lahdemaki', 'blueCorner_reach'] = '62'

df.loc[df['blueCorner'] == 'Shunichi Shimizu', 'blueCorner_reach'] = '66'

df.at[5111, 'blueCorner_reach'] = '64'

df.loc[df['blueCorner'] == 'Josh Clopton', 'blueCorner_reach'] = '68'

df.loc[df['blueCorner'] == 'Azamat Gashimov', 'blueCorner_reach'] = '67'

df.at[5194, 'blueCorner_reach'] = '64'

df.loc[df['blueCorner'] == 'Motonobu Tezuka', 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Ulysses Gomez', 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Pedro Nobre', 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Eiji Mitsuoka', 'blueCorner_reach'] = '68'

df.at[5462, 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Wagner Campos', 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Bernardo Magalhaes', 'blueCorner_reach'] = '68'

df.loc[df['blueCorner'] == 'Eddie Yagin', 'blueCorner_reach'] = '69'

df.at[5682, 'blueCorner_reach'] = '66'

df.loc[df['blueCorner'] == 'Jason Reinhardt', 'blueCorner_reach'] = '64'

df.at[5976, 'blueCorner_reach'] = '69'

df.loc[df['blueCorner'] == 'Jesus Pinedo', 'blueCorner_reach'] = '74'

df.loc[df['blueCorner'] == 'Azunna Anyanwu', 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Abdul Kerim Edilov', 'blueCorner_reach'] = '78'

df.loc[df['blueCorner'] == 'Nick Roehrick', 'blueCorner_reach'] = '76'

df.loc[df['blueCorner'] == 'Tom Gallicchio', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Jim Wallhead', 'blueCorner_reach'] = '74'

df.loc[df['blueCorner'] == 'Michael McBride', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Cindy Dandois', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'JC Cottrell', 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Jonathan Meunier', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Jason Novelli', 'blueCorner_reach'] = '76'

df.loc[df['blueCorner'] == 'Chris Avila', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Leonardo Guimaraes', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Enrique Marin', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Fernando Bruno', 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Anton Zafir', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Mehdi Baghdad', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Martin Svensson', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Felipe Olivieri', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Marcin Wrzosek', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Konstantin Erokhin', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Abner Lloveras', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Leo Kuntz', 'blueCorner_reach'] = '74'

df.at[4040, 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Roger Zapata', 'blueCorner_reach'] = '74'

df.loc[df['blueCorner'] == 'Nazareno Malegarie', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Hans Stringer', 'blueCorner_reach'] = '74'

df.loc[df['blueCorner'] == 'Joe Merritt', 'blueCorner_reach'] = '73'

df.at[4206, 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Antonio Dos Santos', 'blueCorner_reach'] = '72'

df.at[4328, 'blueCorner_reach'] = '79'

df.loc[df['blueCorner'] == 'Cain Carrizosa', 'blueCorner_reach'] = '74'

df.loc[df['blueCorner'] == 'Roger Narvaez', 'blueCorner_reach'] = '80'

df.loc[df['blueCorner'] == 'Josh Copeland', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Alex Torres', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Josh Shockley', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Rodrigo de Lima', 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Mats Nilsson', 'blueCorner_reach'] = '75'

df.at[4471, 'blueCorner_reach'] = '79'

df.loc[df['blueCorner'] == 'Humberto Brown Morrison', 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Guto Inocente', 'blueCorner_reach'] = '77'

df.loc[df['blueCorner'] == 'Takenori Sato', 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Dashon Johnson', 'blueCorner_reach'] = '71'

df.at[4619, 'blueCorner_reach'] = '75'

df.at[4629, 'blueCorner_reach'] = '78'

df.loc[df['blueCorner'] == 'Guilherme Vasconcelos', 'blueCorner_reach'] = '74'

df.at[4799, 'blueCorner_reach'] = '78'

df.at[4852, 'blueCorner_reach'] = '75'

df.loc[df['blueCorner'] == 'Brian Houston', 'blueCorner_reach'] = '78'

df.loc[df['blueCorner'] == 'Will Chope', 'blueCorner_reach'] = '76'

df.loc[df['blueCorner'] == 'Quinn Mulhern', 'blueCorner_reach'] = '76'

df.loc[df['blueCorner'] == 'Dave Galera', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Peggy Morgan', 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Brian Melancon', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Roger Hollett', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Gilbert Smith', 'blueCorner_reach'] = '76'

df.loc[df['blueCorner'] == 'Collin Hart', 'blueCorner_reach'] = '76'

df.loc[df['blueCorner'] == 'Jimmy Quinlan', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Adam Cella', 'blueCorner_reach'] = '74'

df.loc[df['blueCorner'] == 'Besam Yousef', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Brock Jardine', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Milton Vieira', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'CJ Keith', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Byron Bloodworth', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Shane del Rosario', 'blueCorner_reach'] = '78'

df.loc[df['blueCorner'] == 'John Cofer', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Manuel Rodriguez', 'blueCorner_reach'] = '74'

df.loc[df['blueCorner'] == 'Tom DeBlass', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Joey Gambino', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Tommy Hayden', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Yoislandy Izquierdo', 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Luis Ramos', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Pat Schilling', 'blueCorner_reach'] = '70'

df.at[5533, 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Nick Denis', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Eric Wisely', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Stephen Bass', 'blueCorner_reach'] = '73'

df.at[5704, 'blueCorner_reach'] = '72'

df.at[5705, 'blueCorner_reach'] = '73'

df.loc[df['blueCorner'] == 'Donny Walker', 'blueCorner_reach'] = '71'

df.loc[df['blueCorner'] == 'Mike Stumpf', 'blueCorner_reach'] = '71'

df.at[5769, 'blueCorner_reach'] = '72'

df.at[5804, 'blueCorner_reach'] = '72'

df.at[5870, 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Gabe Ruediger', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Willamy Freire', 'blueCorner_reach'] = '70'

df.loc[df['blueCorner'] == 'Antonio McKee', 'blueCorner_reach'] = '72'

df.loc[df['blueCorner'] == 'Aaron Wilkinson', 'blueCorner_reach'] = '72'

df.at[5970, 'blueCorner_reach'] = '70'

df.at[6012, 'blueCorner_reach'] = '80'

df.at[6105, 'blueCorner_reach'] = '72'

df.at[6105, 'blueCorner_reach'] = '72'

df.at[6160, 'blueCorner_reach'] = '77'

df.loc[df['blueCorner'] == 'Michel Batista', 'blueCorner_reach'] = '81'

df.loc[df['blueCorner'] == 'Christian Colombo', 'blueCorner_reach'] = '81'

df.loc[df['blueCorner'] == 'Jon Olav Einemo', 'blueCorner_reach'] = '81'

df.at[5991, 'blueCorner_reach'] = '70'

df.at[6083, 'blueCorner_reach'] = '74'

# %%
redCorner_reaches = df.loc[:6161, 'redCorner_reach'].tolist()
blueCorner_reaches = df.loc[:6161, 'blueCorner_reach'].tolist()
print(list(set(redCorner_reaches)))
print(list(set(blueCorner_reaches)))
# Out:
# ['60"', '82', '71"', '70', '65', '67"', '62"', '62', '66"', '67', '77"', '75', '72"', '75"', '69', '76"', '80"', '61"', '65"', '68', '63', '72', '58"', '73"', '79"', '59"', '79', '81"', '64', '78', '68"', '83"', '74', '66', '74"', '64"', '82"', '76', '84"', '63"', '78"', '71', '73', '70"', '69"', '77']
# ['60"', '82', '71"', '70', '65', '67"', '62"', '80', '62', '66"', '67', '61', '77"', '75', '72"', '75"', '69', '76"', '61"', '80"', '65"', '68', '63', '72', '58"', '73"', '79"', '59"', '81', '79', '81"', '64', '78', '68"', '83"', '74', '66', '74"', '64"', '82"', '76', '84"', '63"', '78"', '71', '73', '70"', '69"', '77']

# %%
df.to_csv('databaseUpdate-01.24.2024.csv', index=False)
